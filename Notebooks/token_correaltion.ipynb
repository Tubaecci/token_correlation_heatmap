# %% [markdown]
# ### Load Joblib

# %%
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the DataFrame
save_path = "C:\\Users\\tobec\\OneDrive\\Documents\\token_heatmap\\Database\\df_prices.joblib"
df_prices_loaded = joblib.load(save_path)

print(df_prices_loaded.head())
# Out:
#                            bitcoin     ethereum      solana
# timestamp
# 2025-07-15 08:00:00  116782.730361  2979.628130  159.731998
# 2025-07-15 09:00:00  116748.498221  2974.418263  159.202684
# 2025-07-15 10:00:00  116813.135616  2973.396934  159.391260
# 2025-07-15 11:00:00  117048.854293  2972.814100  159.573352
# 2025-07-15 12:00:00  116997.940525  2975.543264  159.751575

# %% [markdown]
# ### Token Correlation Heatmap

# %%
# Calculate the correlation matrix
corr = df_prices_loaded.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Token Volatility

# %%
# Compute volatility (standard deviation of returns) for each token

# Calculate log returns
returns = df_prices_loaded.pct_change().apply(lambda x: np.log1p(x))

# Compute volatility (standard deviation of log returns)
volatility = returns.std()

print("Volatility for each token:")
print(volatility)
# Out:
# Volatility for each token:
# bitcoin     0.003046
# ethereum    0.006563
# solana      0.007429
# dtype: float64

# %% [markdown]
# ### Correlation of Tokens Return

# %%
print(returns.head())
# Out:
#                       bitcoin  ethereum    solana
# timestamp
# 2025-07-15 08:00:00       NaN       NaN       NaN
# 2025-07-15 09:00:00 -0.000293 -0.001750 -0.003319
# 2025-07-15 10:00:00  0.000553 -0.000343  0.001184
# 2025-07-15 11:00:00  0.002016 -0.000196  0.001142
# 2025-07-15 12:00:00 -0.000435  0.000918  0.001116

# %%
# Calculate the correlation matrix
corr = returns.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()
